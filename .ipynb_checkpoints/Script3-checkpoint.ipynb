# %%
import pandas as pd
import re

# --- Carga de Datos ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.\n")

    # --- Función para Calcular Riqueza de Vocabulario (Type-Token Ratio) ---
    def calcular_ttr(texto):
        if pd.isna(texto) or texto.strip() == "":
            return 0
        palabras = re.findall(r'\b\w+\b', texto.lower())
        if not palabras:
            return 0
        palabras_unicas = set(palabras)
        return len(palabras_unicas) / len(palabras)

    # --- 1. Calcular Métricas de Participación por Bloque ---
    # La clave es agrupar por 'email' Y 'Bloque temático'
    participacion_df = df.groupby(['email', 'Bloque temático']).agg(
        respuestas_por_bloque=('pk_id', 'count'),
        argumentos_por_bloque=('reason', 'count')
    ).reset_index()
    
    participacion_df['tasa_argumentacion_bloque_%'] = \
        (participacion_df['argumentos_por_bloque'] / participacion_df['respuestas_por_bloque'] * 100).round(2)

    # --- 2. Calcular Métricas de Calidad de Argumentos por Bloque ---
    reason_df = df.dropna(subset=['reason']).copy()
    
    # Agrupar argumentos por participante y por bloque
    argumentos_agrupados = reason_df.groupby(['email', 'Bloque temático'])['reason'].apply(lambda x: ' '.join(x)).reset_index()
    argumentos_agrupados.columns = ['email', 'Bloque temático', 'texto_completo_argumentos']
    
    # Calcular métricas de calidad
    reason_df['longitud_argumento'] = reason_df['reason'].str.len()
    longitud_promedio = reason_df.groupby(['email', 'Bloque temático'])['longitud_argumento'].mean().round(2).reset_index()
    longitud_promedio.columns = ['email', 'Bloque temático', 'longitud_promedio_argumento']
    
    argumentos_agrupados['riqueza_vocabulario_ttr'] = argumentos_agrupados['texto_completo_argumentos'].apply(calcular_ttr).round(3)

    # --- 3. Unir todo en una Tabla de Puntuación Granular ---
    scorecard_df = pd.merge(participacion_df, longitud_promedio, on=['email', 'Bloque temático'], how='left')
    scorecard_df = pd.merge(scorecard_df, argumentos_agrupados[['email', 'Bloque temático', 'riqueza_vocabulario_ttr']], on=['email', 'Bloque temático'], how='left')
    
    scorecard_df.fillna(0, inplace=True)
    
    # --- 4. Mostrar los Resultados ---
    # Ordenamos por la cantidad de argumentos para ver las participaciones cualitativas más significativas
    scorecard_df_sorted = scorecard_df.sort_values(by='argumentos_por_bloque', ascending=False)
    
    print("--- Tabla de Puntuación Granular de Participantes (Top 15 por N° de Argumentos en un Bloque) ---")
    print(scorecard_df_sorted.head(15).to_string())

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
#
# --- Tabla de Puntuación Granular de Participantes (Top 15 por N° de Argumentos en un Bloque) ---
#                                         email                                                                                                   Bloque temático  respuestas_por_bloque  argumentos_por_bloque  tasa_argumentacion_bloque_%  longitud_promedio_argumento  riqueza_vocabulario_ttr
# 137                        dhiglesi@gmail.com  Bloque 1: Incertidumbres críticas sobre la Agroindustria Alimentaria Argentina, en el contexto mundial (1 a 12)                      48                     48                       100.00                       244.90                    0.344
# ...

# %%
import pandas as pd
import re

def calcular_ttr(texto):
    """Calcula la Riqueza de Vocabulario (Type-Token Ratio) de un texto."""
    if pd.isna(texto) or texto.strip() == "":
        return 0
    palabras = re.findall(r'\b\w+\b', texto.lower())
    if not palabras:
        return 0
    palabras_unicas = set(palabras)
    return len(palabras_unicas) / len(palabras)

def crear_scorecard_granular(dataframe):
    """Procesa el dataframe principal y crea la tabla de puntuación por participante y por bloque."""
    # 1. Calcular Métricas de Participación por Bloque
    participacion_df = dataframe.groupby(['email', 'Bloque temático']).agg(
        respuestas_por_bloque=('pk_id', 'count'),
        argumentos_por_bloque=('reason', 'count')
    ).reset_index()
    participacion_df['tasa_argumentacion_bloque_%'] = \
        (participacion_df['argumentos_por_bloque'] / participacion_df['respuestas_por_bloque'] * 100).round(2)

    # 2. Calcular Métricas de Calidad de Argumentos por Bloque
    reason_df = dataframe.dropna(subset=['reason']).copy()
    argumentos_agrupados = reason_df.groupby(['email', 'Bloque temático'])['reason'].apply(lambda x: ' '.join(x)).reset_index()
    argumentos_agrupados.columns = ['email', 'Bloque temático', 'texto_completo_argumentos']
    
    reason_df['longitud_argumento'] = reason_df['reason'].str.len()
    longitud_promedio = reason_df.groupby(['email', 'Bloque temático'])['longitud_argumento'].mean().round(2).reset_index()
    longitud_promedio.columns = ['email', 'Bloque temático', 'longitud_promedio_argumento']
    
    argumentos_agrupados['riqueza_vocabulario_ttr'] = argumentos_agrupados['texto_completo_argumentos'].apply(calcular_ttr).round(3)

    # 3. Unir todo en una Tabla de Puntuación Granular
    scorecard_df = pd.merge(participacion_df, longitud_promedio, on=['email', 'Bloque temático'], how='left')
    scorecard_df = pd.merge(scorecard_df, argumentos_agrupados[['email', 'Bloque temático', 'riqueza_vocabulario_ttr']], on=['email', 'Bloque temático'], how='left')
    
    scorecard_df.fillna(0, inplace=True)
    return scorecard_df

def mostrar_ranking_por_bloque(scorecard, nombre_categoria, top_n=10, sort_by='argumentos_por_bloque'):
    """Filtra el scorecard para un bloque temático y muestra un ranking de los mejores participantes."""
    print("\n" + "="*80)
    print(f"### Ranking de Participantes para el Bloque: '{nombre_categoria.split(':')[0]}'")
    print("="*80)
    
    ranking_df = scorecard[scorecard['Bloque temático'] == nombre_categoria].copy()
    
    if ranking_df.empty:
        print("No hay datos de participación para este bloque temático.")
        return
        
    ranking_df_sorted = ranking_df.sort_values(by=sort_by, ascending=False)
    
    # Seleccionar y reordenar columnas para una mejor visualización
    columnas_display = [
        'email', 
        'argumentos_por_bloque', 
        'respuestas_por_bloque', 
        'tasa_argumentacion_bloque_%', 
        'longitud_promedio_argumento', 
        'riqueza_vocabulario_ttr'
    ]
    print(ranking_df_sorted[columnas_display].head(top_n).to_string())


# --- Carga de Datos y Ejecución ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.")
    
    # 1. Crear la tabla de puntuación base
    scorecard_granular = crear_scorecard_granular(df)
    print("Tabla de puntuación granular creada con éxito.")
    
    # 2. Usar la nueva función para mostrar el ranking de un bloque específico
    bloque_a_consultar = "Bloque 1: Incertidumbres críticas sobre la Agroindustria Alimentaria Argentina, en el contexto mundial (1 a 12) "
    mostrar_ranking_por_bloque(scorecard_granular, bloque_a_consultar)
    
except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
# Tabla de puntuación granular creada con éxito.
#
# ...
# ### Ranking de Participantes para el Bloque: 'Bloque 1'
# ...
#                                         email  argumentos_por_bloque  respuestas_por_bloque  tasa_argumentacion_bloque_%  longitud_promedio_argumento  riqueza_vocabulario_ttr
# 137                        dhiglesi@gmail.com                     48                     48                       100.00                       244.90                    0.344
# 14                    adriana.bocco@gmail.com                     43                     45                        95.56                       405.37                    0.254
# 347                        leonca45@gmail.com                     29                     48                        60.42                       279.62                    0.342
# ...

# %%
import pandas as pd
import re

def calcular_ttr(texto):
    """Calcula la Riqueza de Vocabulario (Type-Token Ratio) de un texto."""
    if pd.isna(texto) or texto.strip() == "":
        return 0
    palabras = re.findall(r'\b\w+\b', texto.lower())
    if not palabras:
        return 0
    palabras_unicas = set(palabras)
    return len(palabras_unicas) / len(palabras)

def crear_scorecard_granular(dataframe):
    """Procesa el dataframe principal y crea la tabla de puntuación por participante y por bloque."""
    participacion_df = dataframe.groupby(['email', 'Bloque temático']).agg(
        respuestas_por_bloque=('pk_id', 'count'),
        argumentos_por_bloque=('reason', 'count')
    ).reset_index()
    participacion_df['tasa_argumentacion_bloque_%'] = \
        (participacion_df['argumentos_por_bloque'] / participacion_df['respuestas_por_bloque'] * 100).round(2)

    reason_df = dataframe.dropna(subset=['reason']).copy()
    argumentos_agrupados = reason_df.groupby(['email', 'Bloque temático'])['reason'].apply(lambda x: ' '.join(x)).reset_index()
    argumentos_agrupados.columns = ['email', 'Bloque temático', 'texto_completo_argumentos']
    
    reason_df['longitud_argumento'] = reason_df['reason'].str.len()
    longitud_promedio = reason_df.groupby(['email', 'Bloque temático'])['longitud_argumento'].mean().round(2).reset_index()
    longitud_promedio.columns = ['email', 'Bloque temático', 'longitud_promedio_argumento']
    
    argumentos_agrupados['riqueza_vocabulario_ttr'] = argumentos_agrupados['texto_completo_argumentos'].apply(calcular_ttr).round(3)

    scorecard_df = pd.merge(participacion_df, longitud_promedio, on=['email', 'Bloque temático'], how='left')
    scorecard_df = pd.merge(scorecard_df, argumentos_agrupados[['email', 'Bloque temático', 'riqueza_vocabulario_ttr']], on=['email', 'Bloque temático'], how='left')
    
    scorecard_df.fillna(0, inplace=True)
    return scorecard_df

def mostrar_ranking_por_bloque(scorecard, nombre_categoria, top_n=5, sort_by='argumentos_por_bloque'):
    """Filtra el scorecard para un bloque temático y muestra un ranking de los mejores participantes."""
    print("\n" + "="*80)
    print(f"### Ranking de Participantes para el Bloque: '{nombre_categoria.split(':')[0].strip()}'")
    print("="*80)
    
    ranking_df = scorecard[scorecard['Bloque temático'] == nombre_categoria].copy()
    
    if ranking_df.empty:
        print("No hay datos de participación para este bloque temático.")
        return
        
    ranking_df_sorted = ranking_df.sort_values(by=sort_by, ascending=False)
    
    columnas_display = [
        'email', 
        'argumentos_por_bloque', 
        'respuestas_por_bloque', 
        'tasa_argumentacion_bloque_%', 
        'longitud_promedio_argumento', 
        'riqueza_vocabulario_ttr'
    ]
    print(ranking_df_sorted[columnas_display].head(top_n).to_string())


# --- Carga de Datos y Ejecución ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.")
    
    # 1. Crear la tabla de puntuación base granular
    scorecard_granular = crear_scorecard_granular(df)
    print("Tabla de puntuación granular creada con éxito.")
    
    # 2. (PARTE 1) Mostrar el Top 5 para CADA bloque temático
    categories = df['Bloque temático'].dropna().unique()
    for category in categories:
        mostrar_ranking_por_bloque(scorecard_granular, category, top_n=5)
        
    # 3. (PARTE 2) Calcular y mostrar el Top General de expertos
    print("\n\n" + "="*80)
    print("### Ranking de Participantes a Nivel General")
    print("="*80)
    
    # Agrupar la tabla granular para obtener métricas generales por experto
    scorecard_general = scorecard_granular.groupby('email').agg(
        bloques_participados=('Bloque temático', 'count'),
        total_argumentos_globales=('argumentos_por_bloque', 'sum'),
        total_respuestas_globales=('respuestas_por_bloque', 'sum'),
        longitud_promedio_global=('longitud_promedio_argumento', 'mean'),
        riqueza_vocabulario_promedio=('riqueza_vocabulario_ttr', 'mean')
    ).round(2).reset_index()

    # Ordenar por el total de argumentos y luego por la cantidad de bloques participados
    scorecard_general_sorted = scorecard_general.sort_values(
        by=['total_argumentos_globales', 'bloques_participados'], 
        ascending=False
    )
    
    print("Top 15 expertos según su contribución cualitativa total y la cantidad de bloques en que participaron.")
    print(scorecard_general_sorted.head(15).to_string())

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
# Tabla de puntuación granular creada con éxito.
#
# ...
# ### Ranking de Participantes para el Bloque: 'Bloque 1'
# ...
#                          email  argumentos_por_bloque  respuestas_por_bloque  tasa_argumentacion_bloque_%  longitud_promedio_argumento  riqueza_vocabulario_ttr
# 137         dhiglesi@gmail.com                     48                     48                       100.00                       244.90                    0.344
# 14     adriana.bocco@gmail.com                     43                     45                        95.56                       405.37                    0.254
# 347         leonca45@gmail.com                     29                     48                        60.42                       279.62                    0.342
# 183  eraimondo@fca.uncu.edu.ar                     21                     37                        56.76                       296.24                    0.406
# ...

# %%
import pandas as pd
import re

# --- Carga de Datos ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.\n")

    # --- Funciones para el Scoring de Calidad de Argumentos ---

    def contiene_ejemplo(texto):
        """Verifica si el texto contiene frases que introducen ejemplos."""
        if pd.isna(texto): return False
        frases_ejemplo = ['por ejemplo', 'ej.', 'como es el caso', 'tal como', 'caso de']
        return any(frase in texto.lower() for frase in frases_ejemplo)

    def contiene_datos(texto):
        """Verifica si el texto contiene números (años, porcentajes, cifras)."""
        if pd.isna(texto): return False
        # Busca 4 dígitos seguidos (años), números con '%', o la palabra 'millones'/'miles'
        return bool(re.search(r'\d{4}|\d+%|millones|miles', texto.lower()))

    def usa_lenguaje_causal(texto):
        """Verifica si el texto usa conectores de causa-efecto."""
        if pd.isna(texto): return False
        conectores_causales = ['debido a', 'gracias a', 'por lo tanto', 'consecuencia', 'porque', 'ya que', 'dado que']
        return any(conector in texto.lower() for conector in conectores_causales)

    def tiene_vision_futuro(texto):
        """Verifica si el texto usa lenguaje orientado al futuro."""
        if pd.isna(texto): return False
        terminos_futuro = ['futuro', 'largo plazo', 'tendencia', 'será', 'permitirá', 'impactará', 'podría', 'debería']
        return any(termino in texto.lower() for termino in terminos_futuro)

    # --- Creación de la Tabla de Calidad de Argumentos ---

    # 1. Filtrar el DataFrame para trabajar solo con las filas que tienen argumentos.
    argumentos_df = df.dropna(subset=['reason']).copy()
    
    # 2. Aplicar las funciones de scoring a cada argumento.
    argumentos_df['longitud'] = argumentos_df['reason'].str.len()
    argumentos_df['contiene_ejemplo'] = argumentos_df['reason'].apply(contiene_ejemplo)
    argumentos_df['contiene_datos'] = argumentos_df['reason'].apply(contiene_datos)
    argumentos_df['usa_lenguaje_causal'] = argumentos_df['reason'].apply(usa_lenguaje_causal)
    argumentos_df['tiene_vision_futuro'] = argumentos_df['reason'].apply(tiene_vision_futuro)
    
    # 3. Calcular un "Score de Calidad" sumando los True (que valen 1).
    columnas_score = ['contiene_ejemplo', 'contiene_datos', 'usa_lenguaje_causal', 'tiene_vision_futuro']
    argumentos_df['score_calidad'] = argumentos_df[columnas_score].sum(axis=1)

    # 4. Ordenar para ver los argumentos con mayor score y longitud.
    argumentos_calificados_sorted = argumentos_df.sort_values(by=['score_calidad', 'longitud'], ascending=[False, False])
    
    # 5. Mostrar los resultados.
    print("--- Top 15 Argumentos de Mayor Calidad (según Score y Longitud) ---")
    
    # Seleccionamos columnas relevantes para mostrar
    columnas_display = [
        'email',
        'Bloque temático',
        'reason',
        'score_calidad',
        'longitud'
    ]
    # Usamos .to_string() para asegurar que se muestre todo el contenido de la celda 'reason'
    print(argumentos_calificados_sorted[columnas_display].head(15).to_string())

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
#
# --- Top 15 Argumentos de Mayor Calidad (según Score y Longitud) ---
# ...

# %%
import pandas as pd
import re

# --- Carga de Datos ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.\n")

    # --- Funciones para el Scoring de Calidad de Argumentos ---

    def contiene_ejemplo(texto):
        """Verifica si el texto contiene frases que introducen ejemplos."""
        if pd.isna(texto): return False
        frases_ejemplo = ['por ejemplo', 'ej.', 'como es el caso', 'tal como', 'caso de']
        return any(frase in texto.lower() for frase in frases_ejemplo)

    def contiene_datos(texto):
        """Verifica si el texto contiene números (años, porcentajes, cifras)."""
        if pd.isna(texto): return False
        # Busca 4 dígitos seguidos (años), números con '%', o la palabra 'millones'/'miles'
        return bool(re.search(r'\d{4}|\d+%|millones|miles', texto.lower()))

    def usa_lenguaje_causal(texto):
        """Verifica si el texto usa conectores de causa-efecto."""
        if pd.isna(texto): return False
        conectores_causales = ['debido a', 'gracias a', 'por lo tanto', 'consecuencia', 'porque', 'ya que', 'dado que']
        return any(conector in texto.lower() for conector in conectores_causales)

    def tiene_vision_futuro(texto):
        """Verifica si el texto usa lenguaje orientado al futuro."""
        if pd.isna(texto): return False
        terminos_futuro = ['futuro', 'largo plazo', 'tendencia', 'será', 'permitirá', 'impactará', 'podría', 'debería']
        return any(termino in texto.lower() for termino in terminos_futuro)

    # --- Creación de la Tabla de Calidad de Argumentos ---

    # 1. Filtrar el DataFrame para trabajar solo con las filas que tienen argumentos.
    argumentos_df = df.dropna(subset=['reason']).copy()
    
    # 2. Aplicar las funciones de scoring a cada argumento.
    argumentos_df['longitud'] = argumentos_df['reason'].str.len()
    argumentos_df['contiene_ejemplo'] = argumentos_df['reason'].apply(contiene_ejemplo)
    argumentos_df['contiene_datos'] = argumentos_df['reason'].apply(contiene_datos)
    argumentos_df['usa_lenguaje_causal'] = argumentos_df['reason'].apply(usa_lenguaje_causal)
    argumentos_df['tiene_vision_futuro'] = argumentos_df['reason'].apply(tiene_vision_futuro)
    
    # 3. Calcular un "Score de Calidad" sumando los True (que valen 1).
    columnas_score = ['contiene_ejemplo', 'contiene_datos', 'usa_lenguaje_causal', 'tiene_vision_futuro']
    argumentos_df['score_calidad'] = argumentos_df[columnas_score].sum(axis=1)

    # 4. Ordenar para ver los argumentos con mayor score y longitud.
    argumentos_calificados_sorted = argumentos_df.sort_values(by=['score_calidad', 'longitud'], ascending=[False, False])
    
    # 5. Mostrar los resultados.
    print("--- Top 15 Argumentos de Mayor Calidad (según Score y Longitud) ---")
    
    # Seleccionamos columnas relevantes para mostrar
    columnas_display = [
        'email',
        'Bloque temático',
        'reason',
        'score_calidad',
        'longitud'
    ]
    # Usamos .to_string() para asegurar que se muestre todo el contenido de la celda 'reason'
    print(argumentos_calificados_sorted[columnas_display].head(15).to_string())

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
#
# --- Top 15 Argumentos de Mayor Calidad (según Score y Longitud) ---
# ...

# %%
import pandas as pd
import re

def contiene_ejemplo(texto):
    if pd.isna(texto): return False
    return bool(re.search(r'por ejemplo|ej\.|como es el caso|tal como|caso de', texto, re.IGNORECASE))

def contiene_datos(texto):
    if pd.isna(texto): return False
    return bool(re.search(r'\d{4}|\d+%|millones|miles|ha\b|tn\b', texto, re.IGNORECASE))

def usa_lenguaje_causal(texto):
    if pd.isna(texto): return False
    return bool(re.search(r'debido a|gracias a|por lo tanto|consecuencia|porque|ya que|dado que', texto, re.IGNORECASE))

def tiene_vision_futuro(texto):
    if pd.isna(texto): return False
    return bool(re.search(r'futuro|largo plazo|tendencia|será|permitirá|impactará|podría|debería', texto, re.IGNORECASE))

def crear_scorecard_enriquecido(dataframe):
    participacion_df = dataframe.groupby(['email', 'Bloque temático']).agg(
        respuestas_por_bloque=('pk_id', 'count'),
        argumentos_por_bloque=('reason', 'count')
    ).reset_index()
    participacion_df['tasa_argumentacion_bloque_%'] = \
        (participacion_df['argumentos_por_bloque'] / participacion_df['respuestas_por_bloque'] * 100).round(2)

    argumentos_df = dataframe.dropna(subset=['reason']).copy()
    argumentos_df['contiene_ejemplo'] = argumentos_df['reason'].apply(contiene_ejemplo)
    argumentos_df['contiene_datos'] = argumentos_df['reason'].apply(contiene_datos)
    argumentos_df['usa_lenguaje_causal'] = argumentos_df['reason'].apply(usa_lenguaje_causal)
    argumentos_df['tiene_vision_futuro'] = argumentos_df['reason'].apply(tiene_vision_futuro)
    argumentos_df['score_calidad'] = argumentos_df[['contiene_ejemplo', 'contiene_datos', 'usa_lenguaje_causal', 'tiene_vision_futuro']].sum(axis=1)

    calidad_agregada_df = argumentos_df.groupby(['email', 'Bloque temático']).agg(
        score_calidad_promedio=('score_calidad', 'mean'),
        score_calidad_total=('score_calidad', 'sum'),
        longitud_promedio_argumento=('reason', lambda x: x.str.len().mean())
    ).round(2).reset_index()

    scorecard_enriquecido = pd.merge(participacion_df, calidad_agregada_df, on=['email', 'Bloque temático'], how='left')
    scorecard_enriquecido.fillna(0, inplace=True)
    return scorecard_enriquecido

nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    
    scorecard_granular = crear_scorecard_enriquecido(df)
    
    scorecard_general = scorecard_granular.groupby('email').agg(
        bloques_participados=('Bloque temático', 'count'),
        total_argumentos_globales=('argumentos_por_bloque', 'sum'),
        score_calidad_total_global=('score_calidad_total', 'sum'),
        score_calidad_promedio_global=('score_calidad_promedio', 'mean')
    ).round(2).reset_index()
    
    print("✓ Proceso de scoring completado. Las tablas 'scorecard_granular' y 'scorecard_general' han sido creadas.")

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# ✓ Proceso de scoring completado. Las tablas 'scorecard_granular' y 'scorecard_general' han sido creadas.

# %%
def mostrar_ranking_por_bloque(scorecard, nombre_categoria, top_n=5):
    print("\n" + "="*80)
    print(f"### Ranking de Participantes para el Bloque: '{nombre_categoria.split(':')[0].strip()}'")
    print("="*80)
    
    ranking_df = scorecard[scorecard['Bloque temático'] == nombre_categoria].copy()
    if ranking_df.empty:
        print("No hay datos de participación para este bloque temático.")
        return
        
    ranking_df_sorted = ranking_df.sort_values(by=['score_calidad_total', 'argumentos_por_bloque'], ascending=False)
    
    columnas_display = [
        'email', 
        'argumentos_por_bloque',
        'score_calidad_promedio',
        'score_calidad_total',
        'longitud_promedio_argumento', 
        'tasa_argumentacion_bloque_%'
    ]
    print(ranking_df_sorted[columnas_display].head(top_n).to_string())

# Verificar que los scorecards existen antes de intentar usarlos
if 'scorecard_granular' in locals() and 'scorecard_general' in locals():
    print("Iniciando la visualización de rankings...\n")
    
    # Parte 1: Mostrar Top 5 para cada bloque temático
    categories = scorecard_granular['Bloque temático'].dropna().unique()
    for category in categories:
        mostrar_ranking_por_bloque(scorecard_granular, category, top_n=5)
        
    # Parte 2: Mostrar el Top General de expertos
    print("\n\n" + "="*80)
    print("### Ranking General de Expertos Destacados")
    print("="*80)
    
    scorecard_general_sorted = scorecard_general.sort_values(
        by=['score_calidad_total_global', 'total_argumentos_globales'], 
        ascending=False
    )
    
    print("Top 15 expertos según el score de calidad acumulado y la cantidad total de argumentos.")
    print(scorecard_general_sorted.head(15).to_string())

else:
    print("Error: Las tablas de puntuación ('scorecard_granular' y 'scorecard_general') no fueron encontradas.")
    print("Por favor, asegúrate de ejecutar el 'Bloque de Código 1' primero y sin errores.")
# Out:
# Iniciando la visualización de rankings...
#
#
# ...
# ### Ranking de Participantes para el Bloque: 'Bloque 1'
# ...
#                           email  argumentos_por_bloque  score_calidad_promedio  score_calidad_total  longitud_promedio_argumento  tasa_argumentacion_bloque_%
# 14      adriana.bocco@gmail.com                     43                    0.44                 19.0                       405.37                        95.56
# 347          leonca45@gmail.com                     29                    0.52                 15.0                       279.62                        60.42
# 556       rgcarri@mincyt.gov.ar                     16                    0.88                 14.0                       664.75                        33.33
# 162          editho@iica.org.ar                     13                    0.92                 12.0                       555.77                        86.67
# ...

# %%
import pandas as pd
import re
from IPython.display import display, HTML

def calcular_ttr(texto):
    if pd.isna(texto) or texto.strip() == "": return 0
    palabras = re.findall(r'\b\w+\b', texto.lower())
    if not palabras: return 0
    palabras_unicas = set(palabras)
    return len(palabras_unicas) / len(palabras)

def crear_scorecard_enriquecido(dataframe):
    participacion_df = dataframe.groupby(['email', 'Bloque temático']).agg(
        respuestas_por_bloque=('pk_id', 'count'),
        argumentos_por_bloque=('reason', 'count')
    ).reset_index()
    participacion_df['tasa_argumentacion_bloque_%'] = \
        (participacion_df['argumentos_por_bloque'] / participacion_df['respuestas_por_bloque'] * 100).round(2)

    argumentos_df = dataframe.dropna(subset=['reason']).copy()
    argumentos_df['contiene_ejemplo'] = argumentos_df['reason'].apply(lambda x: bool(re.search(r'por ejemplo|ej\.|como es el caso|tal como|caso de', x, re.IGNORECASE)) if pd.notna(x) else False)
    argumentos_df['contiene_datos'] = argumentos_df['reason'].apply(lambda x: bool(re.search(r'\d{4}|\d+%|millones|miles|ha\b|tn\b', x, re.IGNORECASE)) if pd.notna(x) else False)
    argumentos_df['usa_lenguaje_causal'] = argumentos_df['reason'].apply(lambda x: bool(re.search(r'debido a|gracias a|por lo tanto|consecuencia|porque|ya que|dado que', x, re.IGNORECASE)) if pd.notna(x) else False)
    argumentos_df['tiene_vision_futuro'] = argumentos_df['reason'].apply(lambda x: bool(re.search(r'futuro|largo plazo|tendencia|será|permitirá|impactará|podría|debería', x, re.IGNORECASE)) if pd.notna(x) else False)
    argumentos_df['score_calidad'] = argumentos_df[['contiene_ejemplo', 'contiene_datos', 'usa_lenguaje_causal', 'tiene_vision_futuro']].sum(axis=1)

    calidad_agregada_df = argumentos_df.groupby(['email', 'Bloque temático']).agg(
        score_calidad_promedio=('score_calidad', 'mean'),
        score_calidad_total=('score_calidad', 'sum'),
        longitud_promedio_argumento=('reason', lambda x: x.str.len().mean())
    ).round(2).reset_index()

    scorecard_enriquecido = pd.merge(participacion_df, calidad_agregada_df, on=['email', 'Bloque temático'], how='left')
    scorecard_enriquecido.fillna(0, inplace=True)
    return scorecard_enriquecido

def mostrar_ranking_por_bloque_html(scorecard, nombre_categoria, top_n=5):
    header_html = f"<h3>Ranking de Participantes para el Bloque: '{nombre_categoria.split(':')[0].strip()}'</h3>"
    display(HTML(header_html))
    
    ranking_df = scorecard[scorecard['Bloque temático'] == nombre_categoria].copy()
    if ranking_df.empty:
        print("No hay datos de participación para este bloque temático.")
        return
        
    ranking_df_sorted = ranking_df.sort_values(by=['score_calidad_total', 'argumentos_por_bloque'], ascending=False)
    
    columnas_display = {
        'email': 'Email',
        'argumentos_por_bloque': 'N° Arg.',
        'score_calidad_promedio': 'Calidad Prom.',
        'score_calidad_total': 'Score Total',
        'longitud_promedio_argumento': 'Long. Prom.',
        'tasa_argumentacion_bloque_%': 'Tasa Arg. (%)'
    }
    
    display_df = ranking_df_sorted[list(columnas_display.keys())].head(top_n).rename(columns=columnas_display)
    
    # Usamos .to_html() para generar la tabla formateada
    html_output = display_df.to_html(index=False, classes='table table-striped table-bordered text-center', justify='center')
    display(HTML(html_output))

# --- Carga de Datos y Ejecución ---
nombre_archivo_excel = 'tablabase_plana3.xlsx'
try:
    df = pd.read_excel(nombre_archivo_excel)
    print(f"Archivo '{nombre_archivo_excel}' cargado exitosamente.")
    
    scorecard_enriquecido = crear_scorecard_enriquecido(df)
    print("Tabla de puntuación enriquecida creada con éxito.\n")
    
    categories = df['Bloque temático'].dropna().unique()
    for category in categories:
        mostrar_ranking_por_bloque_html(scorecard_enriquecido, category, top_n=5)
        
    # --- Ranking General ---
    header_general_html = f"<h2>Ranking General de Expertos Destacados</h2>"
    display(HTML(header_general_html))
    
    scorecard_general = scorecard_enriquecido.groupby('email').agg(
        bloques_participados=('Bloque temático', 'count'),
        total_argumentos_globales=('argumentos_por_bloque', 'sum'),
        score_calidad_total_global=('score_calidad_total', 'sum'),
        score_calidad_promedio_global=('score_calidad_promedio', 'mean')
    ).round(2).reset_index()

    scorecard_general_sorted = scorecard_general.sort_values(
        by=['score_calidad_total_global', 'total_argumentos_globales'], 
        ascending=False
    )
    
    columnas_general_display = {
        'email': 'Email',
        'bloques_participados': 'N° Bloques',
        'total_argumentos_globales': 'N° Arg. Total',
        'score_calidad_total_global': 'Score Total Global',
        'score_calidad_promedio_global': 'Calidad Prom. Global'
    }
    
    display_general_df = scorecard_general_sorted.head(15).rename(columns=columnas_general_display)
    html_general_output = display_general_df.to_html(index=False, classes='table table-striped table-bordered text-center', justify='center')
    display(HTML(html_general_output))

except FileNotFoundError:
    print(f"Error Crítico: No se encontró el archivo '{nombre_archivo_excel}'.")
except Exception as e:
    print(f"Ocurrió un error inesperado: {e}")
# Out:
# Archivo 'tablabase_plana3.xlsx' cargado exitosamente.
# Tabla de puntuación enriquecida creada con éxito.
# <h3>Ranking de Participantes para el Bloque: 'Bloque 1'</h3>
# <table border="1" class="dataframe table table-striped table-bordered text-center">
#   <thead>
#     <tr style="text-align: center;">
#       <th>Email</th>
#       <th>N° Arg.</th>
#       <th>Calidad Prom.</th>
#       <th>Score Total</th>
#       <th>Long. Prom.</th>
#       <th>Tasa Arg. (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>adriana.bocco@gmail.com</td>
#       <td>43</td>
#       <td>0.44</td>
#       <td>19.0</td>
#       <td>405.37</td>
#       <td>95.56</td>
#     </tr>
#     <tr>
#       <td>leonca45@gmail.com</td>
#       <td>29</td>
#       <td>0.52</td>
#       <td>15.0</td>
#       <td>279.62</td>
#       <td>60.42</td>
#     </tr>
#     <tr>
#       <td>rgcarri@mincyt.gov.ar</td>
#       <td>16</td>
#       <td>0.88</td>
#       <td>14.0</td>
#       <td>664.75</td>
# ...
